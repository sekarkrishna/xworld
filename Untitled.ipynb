# %%
import justviz as jv
import networkx as nx

G = nx.karate_club_graph()
jv.graph(G, color_by="club", node_size=6.0, interactive=True)
# Cell returns immediately, window opens separately

# %%
# Second window (should work without kernel restart)
G2 = nx.barabasi_albert_graph(200, 3)
jv.graph(G2, interactive=True)
print("Second window closed OK")
# Out:
# Second window closed OK
